# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importing Dataset
#
# bl_image = pd.read_table("txtfile", sep = ',')
# bl_image

# %%
#Check Dataset INformation

bl_image.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8288 entries, 0 to 8287
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Identifier              8288 non-null   object
#  1   Edition Statement       773 non-null    object
#  2   Place of Publication    8287 non-null   object
#  3   Date of Publication     8106 non-null   object
#  4   Publisher               4092 non-null   object
#  5   Title                   8287 non-null   object
#  6   Author                  6509 non-null   object
#  7   Contributors            8287 non-null   object
#  8   Corporate Author        0 non-null      float64
#  9   Corporate Contributors  0 non-null      float64
#  10  Former owner            1 non-null      object
#  11  Engraver                0 non-null      float64
#  12  Issuance type           8287 non-null   object
#  13  Flickr URL              8287 non-null   object
# ...

# %%
bl_image.iloc[206]
# Out:
# Identifier                                                        000077554
# Edition Statement                                                       NaN
# Place of Publication                                                 London
# Date of Publication                                                    1848
# Publisher                                                   Richard Bentley
# Title                     Rambles in the romantic regions of the Hartz M...
# Author                                     Andersen, H. C. (Hans Christian)
# Contributors                                    BECKWITH-LOHMEYER, Charles.
# Corporate Author                                                        NaN
# Corporate Contributors                                                  NaN
# Former owner                                                            NaN
# Engraver                                                                NaN
# ...

# %%
#Set "IDENTIFIER" column to INDEX

bl_image.set_index("Identifier",inplace = True)

# %%
#Check Dataset

bl_image
# Out:
#                        Edition Statement      Place of Publication  \
# Identifier
# 000000206                            NaN                    London
# 000000216                            NaN  London; Virtue & Yorston
# 000000218                            NaN                    London
# 000000472                            NaN                    London
# 000000480   A new edition, revised, etc.                    London
# ...                                  ...                       ...
# 004158128                            NaN                     Derby
# 004159563                            NaN                    London
# 004159587                            NaN       Newcastle upon Tyne
# 004160339                            NaN                    London
# pd.rea                               NaN                       NaN
#
#            Date of Publication                Publisher  \
# Identifier
# 000000206          1879 [1878]         S. Tinsley & Co.
# ...

# %%
#Drop unnecessary column

bl_image.drop("pd.rea",axis=0,inplace = True)

# %%
#Checking Totals Columns

bl_image.columns
# Out:
# Index(['Edition Statement', 'Place of Publication', 'Date of Publication',
#        'Publisher', 'Title', 'Author', 'Contributors', 'Corporate Author',
#        'Corporate Contributors', 'Former owner', 'Engraver', 'Issuance type',
#        'Flickr URL', 'Shelfmarks'],
#       dtype='object')

# %%
#Drop unnecessary Columns again

bl_image.drop(columns = ['Edition Statement','Corporate Author',
       'Corporate Contributors', 'Former owner', 'Engraver','Issuance type','Shelfmarks','Flickr URL'], inplace = True)

# %%
#Checking Dataset

bl_image
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 000000206                     London         1879 [1878]
# 000000216   London; Virtue & Yorston                1868
# 000000218                     London                1869
# 000000472                     London                1851
# 000000480                     London                1857
# ...                              ...                 ...
# 004158088                     London                1838
# 004158128                      Derby            1831, 32
# 004159563                     London           [1806]-22
# 004159587        Newcastle upon Tyne                1834
# 004160339                     London             1834-43
#
#                           Publisher  \
# Identifier
# 000000206          S. Tinsley & Co.
# 000000216              Virtue & Co.
# 000000218     Bradbury, Evans & Co.
# 000000472             James Darling
# 000000480      Wertheim & Macintosh
# ...

# %%
#Checking Columns

bl_image.columns
# Out:
# Index(['Place of Publication', 'Date of Publication', 'Publisher', 'Title',
#        'Author', 'Contributors'],
#       dtype='object')

# %%
#Checking information

bl_image.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8287 entries, 000000206 to 004160339
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Place of Publication  8287 non-null   object
#  1   Date of Publication   8106 non-null   object
#  2   Publisher             4092 non-null   object
#  3   Title                 8287 non-null   object
#  4   Author                6509 non-null   object
#  5   Contributors          8287 non-null   object
# dtypes: object(6)
# memory usage: 453.2+ KB

# %%
#Checking Dataset again

bl_image
# Out:
#                 Place of Publication Date of Publication  \
# Identifier
# 000000206                     London         1879 [1878]
# 000000216   London; Virtue & Yorston                1868
# 000000218                     London                1869
# 000000472                     London                1851
# 000000480                     London                1857
# ...                              ...                 ...
# 004158088                     London                1838
# 004158128                      Derby            1831, 32
# 004159563                     London           [1806]-22
# 004159587        Newcastle upon Tyne                1834
# 004160339                     London             1834-43
#
#                           Publisher  \
# Identifier
# 000000206          S. Tinsley & Co.
# 000000216              Virtue & Co.
# 000000218     Bradbury, Evans & Co.
# 000000472             James Darling
# 000000480      Wertheim & Macintosh
# ...

# %% [markdown]
# # Data Cleaning

# %%
#Extracting the "Date of Publication" column data using Regex
bl_image["Date of Publication"] = bl_image["Date of Publication"].str.extract(r"^(\d{4})",expand = False)
bl_image["Date of Publication"]
# Out:
# Identifier
# 000000206    1879
# 000000216    1868
# 000000218    1869
# 000000472    1851
# 000000480    1857
#              ...
# 004158088    1838
# 004158128    1831
# 004159563     NaN
# 004159587    1834
# 004160339    1834
# Name: Date of Publication, Length: 8287, dtype: object

# %%
#Calculating total of one value in column of "Date of Publication"

bl_image["Date of Publication"].value_counts()
# Out:
# 1897    179
# 1896    169
# 1893    140
# 1892    140
# 1891    140
#        ...
# 1653      1
# 1672      1
# 1657      1
# 1635      1
# 1755      1
# Name: Date of Publication, Length: 254, dtype: int64

# %%
#Calculating the null values in "Date of Publication" column

bl_image["Date of Publication"].isnull().sum()
# Out:
# 971

# %%
#Finding the most frequently using value in "Date of Publication" column

bl_image["Date of Publication"].mode()
# Out:
# 0    1897
# dtype: object

# %%
#Filling mode value of "Date of Publication" in place of Nan Values in column

bl_image["Date of Publication"] = bl_image["Date of Publication"].fillna(value = "1897")

# %%
bl_image.isnull().sum()
# Out:
# Place of Publication       0
# Date of Publication        0
# Publisher               4195
# Title                      0
# Author                  1778
# Contributors               0
# dtype: int64

# %%
#Filling Nan Values to "Publisher" column as "Publisher not Known"

bl_image["Publisher"] = bl_image["Publisher"].fillna(value= "Publisher not Known")

# %%
#Filling Nan Values to "Author" column as "Author not Known"

bl_image["Author"] = bl_image["Author"].fillna(value = "Author not none")

# %%
#Checking dataset

bl_image
# Out:
#                 Place of Publication  Date of Publication  \
# Identifier
# 000000206                     London                 1879
# 000000216   London; Virtue & Yorston                 1868
# 000000218                     London                 1869
# 000000472                     London                 1851
# 000000480                     London                 1857
# ...                              ...                  ...
# 004158088                     London                 1838
# 004158128                      Derby                 1831
# 004159563                     London                 1897
# 004159587        Newcastle upon Tyne                 1834
# 004160339                     London                 1834
#
#                           Publisher  \
# Identifier
# 000000206          S. Tinsley & Co.
# 000000216              Virtue & Co.
# 000000218     Bradbury, Evans & Co.
# 000000472             James Darling
# 000000480      Wertheim & Macintosh
# ...

# %%
#checking dataset for Nan values

bl_image.isnull().sum()
# Out:
# Place of Publication    0
# Date of Publication     0
# Publisher               0
# Title                   0
# Author                  0
# Contributors            0
# dtype: int64

# %%
#Checking total number of "London" value present in column "Place of Publication"

bl_image["Place of Publication"].str.contains("London").sum()
# Out:
# 4219

# %%
#Checking total number of "Oxford" value present in column "Place of Publication"

bl_image["Place of Publication"].str.contains("Oxford").sum()
# Out:
# 55

# %%
#Checking all values present in column of "Place of Publication"

bl_image["Place of Publication"].value_counts()
# Out:
# London                     3868
# Paris                       479
# Edinburgh                   208
# New York                    177
# Leipzig                     119
#                            ...
# 2 Bdchn. Berlin               1
# Wrexham?]                     1
# Au Meschacébé [Mons]        1
# Ermanno Loescher              1
# St. Petersburg, Leipzig       1
# Name: Place of Publication, Length: 1441, dtype: int64

# %%
#Removing unwanted values present in column "Place of Publication"
bl_image["Place of Publication"] = np.where(bl_image["Place of Publication"].str.contains("London"), 'London',
                                      np.where(bl_image["Place of Publication"].str.contains("Oxford"), 'Oxford',
                                               bl_image["Place of Publication"].str.replace('-', ' ')))

# %%
#Checking after Removing

bl_image["Place of Publication"]
# Out:
# Identifier
# 000000206                 London
# 000000216                 London
# 000000218                 London
# 000000472                 London
# 000000480                 London
#                     ...
# 004158088                 London
# 004158128                  Derby
# 004159563                 London
# 004159587    Newcastle upon Tyne
# 004160339                 London
# Name: Place of Publication, Length: 8287, dtype: object

# %% [markdown]
# # Final Analyzation & Cleaned Dataset

# %%
bl_image
# Out:
#            Place of Publication  Date of Publication                Publisher  \
# Identifier
# 000000206                London                 1879         S. Tinsley & Co.
# 000000216                London                 1868             Virtue & Co.
# 000000218                London                 1869    Bradbury, Evans & Co.
# 000000472                London                 1851            James Darling
# 000000480                London                 1857     Wertheim & Macintosh
# ...                         ...                  ...                      ...
# 004158088                London                 1838      Publisher not Known
# 004158128                 Derby                 1831          M. Mozley & Son
# 004159563                London                 1897  T. Cadell and W. Davies
# 004159587   Newcastle upon Tyne                 1834         Mackenzie & Dent
# 004160339                London                 1834      Publisher not Known
#
# ...
